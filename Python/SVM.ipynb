# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
df = pd.read_csv('META.csv')

# %%
df.isnull().sum()
# Out:
# Date      0
# Open      0
# High      0
# Low       0
# Close     0
# Volume    0
# dtype: int64

# %%
correlation_matrix = df.drop(columns=['Date']).corr()

print(correlation_matrix)
# Out:
#             Open      High       Low     Close    Volume
# Open    1.000000  0.999830  0.999801  0.999609 -0.371797
# High    0.999830  1.000000  0.999787  0.999819 -0.368912
# Low     0.999801  0.999787  1.000000  0.999840 -0.375346
# Close   0.999609  0.999819  0.999840  1.000000 -0.372393
# Volume -0.371797 -0.368912 -0.375346 -0.372393  1.000000

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10,8))
sns.heatmap(data.corr(), annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Correlation Matrix")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 5
#       2 import matplotlib.pyplot as plt
#       4 plt.figure(figsize=(10,8))
# ----> 5 sns.heatmap(data.corr(), annot=True, cmap='coolwarm', fmt=".2f")
#       6 plt.title("Correlation Matrix")
#       7 plt.show()
#
# NameError: name 'data' is not defined

# %%
import statsmodels.api as sm

# Biến đầu vào (X) và biến mục tiêu (y)
X = data[['Volume', 'Open', 'High', 'Low']]  # các biến độc lập
y = data['Close']  # biến phụ thuộc

# Thêm hệ số chặn (intercept)
X = sm.add_constant(X)

# Huấn luyện mô hình hồi quy tuyến tính
model = sm.OLS(y, X).fit()

# In bảng kết quả
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Close   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                  1.000
# Method:                 Least Squares   F-statistic:                 5.139e+06
# Date:                Wed, 23 Apr 2025   Prob (F-statistic):               0.00
# Time:                        22:23:38   Log-Likelihood:                -6478.4
# No. Observations:                3235   AIC:                         1.297e+04
# Df Residuals:                    3230   BIC:                         1.300e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0179      0.080     -0.225      0.822      -0.174       0.138
# Volume     -3.725e-10   1.41e-09     -0.264      0.792   -3.14e-09    2.39e-09
# Open          -0.5403      0.014    -39.611      0.000      -0.567      -0.514
# High           0.7501      0.014     55.260      0.000       0.723       0.777
# Low            0.7912      0.013     61.004      0.000       0.766       0.817
# ==============================================================================
# Omnibus:                      505.860   Durbin-Watson:                   2.053
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             8769.912
# Skew:                          -0.039   Prob(JB):                         0.00
# Kurtosis:                      11.066   Cond. No.                     9.82e+07
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 9.82e+07. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
df['label'] = (df['Close'].diff() > 0).astype(int)

# %%
df.head()
# Out:
#        Date       Open       High        Low      Close     Volume  label
# 0  18-05-12  41.889986  44.828761  37.855398  38.084522  573576400      0
# 1  21-05-12  36.390988  36.520494  32.874422  33.900501  168192700      0
# 2  22-05-12  32.485908  33.462179  30.822263  30.882034  101786600      0
# 3  23-05-12  31.250625  32.376325  31.240663  31.878227   73600000      1
# 4  24-05-12  32.824611  33.083620  31.649101  32.904305   50237200      1

# %%
# xây dựng SVM
from sklearn import svm
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

# %%
df['Date'] = pd.to_datetime(df['Date'],format='%d-%m-%y')

# %%
df['Day'] = df['Date'].dt.day
df['Month'] = df['Date'].dt.month
df['Year'] = df['Date'].dt.year
df['Quarter'] = df['Date'].dt.quarter   

df = df.drop(columns=['Date'])

# %%
df.isnull().sum()

print(df)
# Out:
#             Open        High         Low       Close     Volume  label  Day  \
# 0      41.889986   44.828761   37.855398   38.084522  573576400      0   18
# 1      36.390988   36.520494   32.874422   33.900501  168192700      0   21
# 2      32.485908   33.462179   30.822263   30.882034  101786600      0   22
# 3      31.250625   32.376325   31.240663   31.878227   73600000      1   23
# 4      32.824611   33.083620   31.649101   32.904305   50237200      1   24
# ...          ...         ...         ...         ...        ...    ...  ...
# 3230  626.760000  633.880000  621.180000  626.310000   15310000      1   25
# 3231  624.890000  626.750000  606.610000  610.980000   12660000      0   26
# 3232  602.000000  614.250000  600.100000  602.580000   10440000      0   27
# 3233  600.310000  601.750000  573.920000  576.740000   17600000      0   28
# 3234  563.500000  578.700000  553.300000  576.360000   21120000      0   31
#
#       Month  Year  Quarter
# 0         5  2012        2
# 1         5  2012        2
# 2         5  2012        2
# 3         5  2012        2
# 4         5  2012        2
# ...     ...   ...      ...
# 3230      3  2025        1
# 3231      3  2025        1
# 3232      3  2025        1
# 3233      3  2025        1
# 3234      3  2025        1
#
# [3235 rows x 10 columns]

# %%
# Chia tập dữ liệu thành tập huấn luyện và tập kiểm tra
# n = len(df)

# train_data = df[:int(n*0.7)]
# test_data = df[int(n*0.7):]

# X_train = train_data.drop(columns=['label'])
# y_train = train_data['label']

# X_test = test_data.drop(columns=['label'])
# y_test = test_data['label']

# print(X_train.shape, y_train.shape)
# print(X_test.shape, y_test.shape)

X = df.drop(columns=['label'])
y = df['label']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=100, stratify=y)


# X_train, X_test, y_train, y_test = train_test_split(df, test_size=0.2, random_state=100)

# %%
# Chuẩn hóa dữ liệu
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
from sklearn.svm import SVC

svm_model = SVC(probability=True, random_state=100)
svm_model.fit(X_train_scaled, y_train)
# Out:
# SVC(probability=True, random_state=100)

# %%
y_pred = svm_model.predict(X_test_scaled)

print("Confusion Matrix:")
print(confusion_matrix(y_test, y_pred))
# Out:
# Confusion Matrix:
# [[ 31 277]
#  [ 33 306]]

# %%
print("\nClassification Report:")
print(classification_report(y_test, y_pred))
print("\nAccuracy:")
print(accuracy_score(y_test, y_pred))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.48      0.10      0.17       308
#            1       0.52      0.90      0.66       339
#
#     accuracy                           0.52       647
#    macro avg       0.50      0.50      0.42       647
# weighted avg       0.51      0.52      0.43       647
#
#
# Accuracy:
# 0.5208655332302936
